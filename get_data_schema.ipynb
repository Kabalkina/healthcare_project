# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/23131-0002_en_2021.csv', sep=';', nrows=100)
df.head()
# Out:
#    statistics_code                   statistics_label time_code time_label  \
# 0            23131  Diagnoses of hospital in-patients      JAHR       Year
# 1            23131  Diagnoses of hospital in-patients      JAHR       Year
# 2            23131  Diagnoses of hospital in-patients      JAHR       Year
# 3            23131  Diagnoses of hospital in-patients      JAHR       Year
# 4            23131  Diagnoses of hospital in-patients      JAHR       Year
#
#    time 1_variable_code 1_variable_label 1_variable_attribute_code  \
# 0  2021           DINSG          Germany                        DG
# 1  2021           DINSG          Germany                        DG
# 2  2021           DINSG          Germany                        DG
# 3  2021           DINSG          Germany                        DG
# 4  2021           DINSG          Germany                        DG
#
#   1_variable_attribute_label 2_variable_code  ... 3_variable_attribute_code  \
# ...

# %%
df.columns
# Out:
# Index(['statistics_code', 'statistics_label', 'time_code', 'time_label',
#        'time', '1_variable_code', '1_variable_label',
#        '1_variable_attribute_code', '1_variable_attribute_label',
#        '2_variable_code', '2_variable_label', '2_variable_attribute_code',
#        '2_variable_attribute_label', '3_variable_code', '3_variable_label',
#        '3_variable_attribute_code', '3_variable_attribute_label',
#        '4_variable_code', '4_variable_label', '4_variable_attribute_code',
#        '4_variable_attribute_label', 'value', 'value_unit',
#        'value_variable_code', 'value_variable_label'],
#       dtype='object')

# %%
df.shape
# Out:
# (100, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   statistics_code             100 non-null    int64
#  1   statistics_label            100 non-null    object
#  2   time_code                   100 non-null    object
#  3   time_label                  100 non-null    object
#  4   time                        100 non-null    int64
#  5   1_variable_code             100 non-null    object
#  6   1_variable_label            100 non-null    object
#  7   1_variable_attribute_code   100 non-null    object
#  8   1_variable_attribute_label  100 non-null    object
#  9   2_variable_code             100 non-null    object
#  10  2_variable_label            100 non-null    object
#  11  2_variable_attribute_code   100 non-null    object
#  12  2_variable_attribute_label  100 non-null    object
# ...

# %%
# Mapping pandas dtypes to SQL types
dtype_mapping = {
    'object': 'text',
    'int64': 'integer',
    'float64': 'double precision',
    'bool': 'boolean',
    'datetime64[ns]': 'timestamp'
}

# %%
# Build SQL columns
columns_sql = []
for col, dtype in df.dtypes.items():
    sql_type = dtype_mapping.get(str(dtype), 'text')  # Default to text if unknown
    columns_sql.append(f"    {col} {sql_type}")

# %%
columns_sql
# Out:
# ['    statistics_code integer',
#  '    statistics_label text',
#  '    time_code text',
#  '    time_label text',
#  '    time integer',
#  '    1_variable_code text',
#  '    1_variable_label text',
#  '    1_variable_attribute_code text',
#  '    1_variable_attribute_label text',
#  '    2_variable_code text',
#  '    2_variable_label text',
#  '    2_variable_attribute_code text',
#  '    2_variable_attribute_label text',
#  '    3_variable_code text',
#  '    3_variable_label text',
#  '    3_variable_attribute_code text',
#  '    3_variable_attribute_label text',
#  '    4_variable_code text',
#  '    4_variable_label text',
#  '    4_variable_attribute_code text',
#  '    4_variable_attribute_label text',
#  '    value integer',
#  '    value_unit text',
#  '    value_variable_code text',
#  '    value_variable_label text']

# %%
df["3_variable_label"].nunique()
# Out:
# 1

# %%
# Mapping pandas dtypes to BigQuery SQL types
dtype_mapping_bq = {
    'object': 'STRING',
    'int64': 'INTEGER',
    'float64': 'NUMERIC',
    'bool': 'BOOLEAN',
    'datetime64[ns]': 'TIMESTAMP'
}

# %%
# Generate field definitions (no description)
columns_sql = []
for col, dtype in df.dtypes.items():
    sql_type = dtype_mapping_bq.get(str(dtype), 'STRING')  # Default to STRING if unknown
    field_def = f"{col} {sql_type}"
    columns_sql.append(field_def)

# %%
columns_sql
# Out:
# ['statistics_code INTEGER',
#  'statistics_label STRING',
#  'time_code STRING',
#  'time_label STRING',
#  'time INTEGER',
#  '1_variable_code STRING',
#  '1_variable_label STRING',
#  '1_variable_attribute_code STRING',
#  '1_variable_attribute_label STRING',
#  '2_variable_code STRING',
#  '2_variable_label STRING',
#  '2_variable_attribute_code STRING',
#  '2_variable_attribute_label STRING',
#  '3_variable_code STRING',
#  '3_variable_label STRING',
#  '3_variable_attribute_code STRING',
#  '3_variable_attribute_label STRING',
#  '4_variable_code STRING',
#  '4_variable_label STRING',
#  '4_variable_attribute_code STRING',
#  '4_variable_attribute_label STRING',
#  'value INTEGER',
#  'value_unit STRING',
#  'value_variable_code STRING',
#  'value_variable_label STRING']

# %%
df.head().transpose()
# Out:
#                                                                   0  \
# statistics_code                                               23131
# statistics_label                  Diagnoses of hospital in-patients
# time_code                                                      JAHR
# time_label                                                     Year
# time                                                           2021
# 1_variable_code                                               DINSG
# 1_variable_label                                            Germany
# 1_variable_attribute_code                                        DG
# 1_variable_attribute_label                                  Germany
# 2_variable_code                                                 GES
# 2_variable_label                                                Sex
# 2_variable_attribute_code                                      GESM
# 2_variable_attribute_label                                     Male
# ...
